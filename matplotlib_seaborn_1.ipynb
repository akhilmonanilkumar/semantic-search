# %%
pip install Matplotlib
# Out:
# Collecting Matplotlib
#   Obtaining dependency information for Matplotlib from https://files.pythonhosted.org/packages/54/af/17195cf1f43cd3be79b15aecc5b7e44ea08456bd0048ad8dcd3a5fd45c45/matplotlib-3.8.4-cp39-cp39-win_amd64.whl.metadata
#   Downloading matplotlib-3.8.4-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from Matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/62/5c/08e3a7a35762c8decb6be01c7ec1f4b5f85ef2e2fbb44af87e9caf25a879/contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata
#   Downloading contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from Matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from Matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/5e/62/ec6247534b077c9627e745d8046027ae363ed6d6407f8010650439ecbda1/fonttools-4.51.0-cp39-cp39-win_amd64.whl.metadata
#   Downloading fonttools-4.51.0-cp39-cp39-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.8 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 2.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from Matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/ca/c1/1f986c8119c0c57c2bd71d1941da23332c38ee2c90117e46dff4358b70f7/kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from Matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from Matplotlib) (24.0)
# Collecting pillow>=8 (from Matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/0b/d7/3a9cfa80a3ff59fddfe3b5bd1cf5728e7ed6608678ce9f23e79f35e87805/pillow-10.3.0-cp39-cp39-win_amd64.whl.metadata
#   Downloading pillow-10.3.0-cp39-cp39-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from Matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from Matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from Matplotlib)
#   Obtaining dependency information for importlib-resources>=3.2.0 from https://files.pythonhosted.org/packages/75/06/4df55e1b7b112d183f65db9503bff189e97179b256e1ea450a3c365241e0/importlib_resources-6.4.0-py3-none-any.whl.metadata
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from importlib-resources>=3.2.0->Matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from python-dateutil>=2.7->Matplotlib) (1.16.0)
# Downloading matplotlib-3.8.4-cp39-cp39-win_amd64.whl (7.7 MB)
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/7.7 MB 12.0 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/7.7 MB 13.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/7.7 MB 13.3 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/7.7 MB 10.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.3/7.7 MB 13.9 MB/s eta 0:00:01
#    -------------------- ------------------- 4.0/7.7 MB 14.2 MB/s eta 0:00:01
#    ------------------------- -------------- 4.8/7.7 MB 14.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.0/7.7 MB 14.5 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.7 MB 14.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.7 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.7 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.7 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 13.2 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
#    ---------------------------------------- 0.0/182.8 kB ? eta -:--:--
#    --------------------------------------- 182.8/182.8 kB 10.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp39-cp39-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------- ---------------------------- 0.6/2.2 MB 19.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 16.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 14.0 MB/s eta 0:00:00
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB 3.1 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp39-cp39-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------- ----------------------------- 0.7/2.5 MB 21.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.5 MB 17.2 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 14.7 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, Matplotlib
# Successfully installed Matplotlib-3.8.4 contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 importlib-resources-6.4.0 kiwisolver-1.4.5 pillow-10.3.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\akhil\pycharmprojects\semantic-search\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------------------- ------------ 204.8/294.9 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame

# %%
data = {'names':['steve','john','richard','sarah','rand','micheal','julie'],
        'age':[20,22,20,21,24,23,22],
        'gender':['Male','Male','Male','Female','Male','Male','Female'],
        'rank':[2,1,4,5,3,7,6]}
df = DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4     rand   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %%
plt.bar(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %%
plot = sns.barplot(data=df, x='names', y= 'age')
plot.set_title('Comparing Ages')
# Out:
# Text(0.5, 1.0, 'Comparing Ages')

# %%
# Line Chart Plotting using seaborn

# %%
plt.plot(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %%
plot = sns.lineplot(data=df, x='names', y='age')
plt.show()

# %%
plt.pie(df['age'], labels = df['names'])
plt.title('Age Comparison')
plt.show()

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels = df['names'], colors= colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1faab513fd0>,
#   <matplotlib.patches.Wedge at 0x1faab513eb0>,
#   <matplotlib.patches.Wedge at 0x1faab4e4220>,
#   <matplotlib.patches.Wedge at 0x1faab45de20>,
#   <matplotlib.patches.Wedge at 0x1faab36a700>,
#   <matplotlib.patches.Wedge at 0x1faab5139a0>,
#   <matplotlib.patches.Wedge at 0x1faaed90ac0>],
#  [Text(1.0073506527883973, 0.4418649820101046, 'steve'),
#   Text(0.3138698181006755, 1.0542702392107297, 'john'),
#   Text(-0.6016430102375324, 0.9208831023709364, 'richard'),
#   Text(-1.0885075285211487, 0.15859180417909632, 'sarah'),
#   Text(-0.7778174593052025, -0.7778174593052023, 'rand'),
#   Text(0.2034389060082334, -1.0810238718558316, 'micheal'),
#   Text(0.9882300812715086, -0.48311624529724506, 'julie')])

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels = df['names'], colors= colors)
plt.show()
